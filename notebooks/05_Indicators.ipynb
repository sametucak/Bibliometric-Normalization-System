# %%
import pandas as pd
import numpy as np
import importlib

# %%
import os
import sys

# Proje ana dizini
PROJECT_ROOT = os.path.abspath("..")

# Python arama yoluna ekle
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project Root:", PROJECT_ROOT)
# Out:
# Project Root: C:\Users\sametucak

# %%
df = pd.read_excel("input/combining yazar listesi.xlsx")

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.columns = [
    "author_full_name",
    "title",
    "journal",
    "year",
    "times_cited",
    "abstract",
    "keywords",
    "affiliation",
    "author"
]

# %%
def clean_text(text):

    if pd.isna(text):
        return ""

    text = str(text)

    text = text.strip()

    text = re.sub(r"\s+", " ", text)

    return text

# %%
for col in df.columns:

    if df[col].dtype == "object":

        df[col] = df[col].apply(clean_text)

# %%
df.isnull().sum()

# %%
df["author_full_name"].nunique()

# %%
df["author_full_name"].value_counts().head(20)

# %%
def normalize_author_name(name):

    if pd.isna(name):
        return ""

    name = str(name)

    # Baştaki ve sondaki boşlukları sil
    name = name.strip()

    # Birden fazla boşluğu teke indir
    name = re.sub(r"\s+", " ", name)

    # Büyük-küçük harfleri düzelt
    name = name.title()

    # Virgülden önce ve sonra boşlukları düzelt
    name = re.sub(r"\s*,\s*", ", ", name)

    return name

# %%
df["normalized_author"] = df["author_full_name"].apply(normalize_author_name)

# %%
df[
    ["author_full_name",
     "normalized_author"]
].head(20)

# %%
df["normalized_author"].nunique()

# %%
import pandas as pd

def split_author(author):

    if pd.isna(author):
        return "", ""

    author = str(author).strip()

    if author == "":
        return "", ""

    if "," in author:

        parts = author.split(",", 1)

        last = parts[0].strip()

        first = parts[1].strip() if len(parts) > 1 else ""

        return last, first

    parts = author.split()

    if len(parts) == 0:
        return "", ""

    if len(parts) == 1:
        return parts[0], ""

    return parts[0], " ".join(parts[1:])

# %%
split_author("Lugli, Gabriele Andrea")

# %%
split_author("Chen Yang")

# %%
def first_initial(first_name):

    if first_name == "":

        return ""

    return first_name[0]

# %%
first_initial("Gabriele Andrea")

# %%
def compare_authors(a1, a2):

    last1, first1 = split_author(a1)
    last2, first2 = split_author(a2)

    if last1 != last2:

        return False

    if first_initial(first1) != first_initial(first2):

        return False

    return True

# %%
compare_authors(
    "Lugli, Gabriele Andrea",
    "Lugli, Gabriele A."
)

# %%
compare_authors(
    "Smith, John",
    "Chen, Yang"
)

# %%
def normalize_first_name(name):

    name = name.lower()

    name = name.replace(".", "")

    name = name.strip()

    return name

# %%
normalize_first_name("Gabriele A.")

# %%
from rapidfuzz import fuzz

def author_score(author1, author2):

    last1, first1 = split_author(author1)
    last2, first2 = split_author(author2)

    score = 0

    # Soyadı
    if last1.lower() == last2.lower():
        score += 40

    # İlk isim benzerliği
    score += fuzz.ratio(
        normalize_first_name(first1),
        normalize_first_name(first2)
    ) * 0.6

    return round(score,2)

# %%
author_score(
    "Lugli, Gabriele Andrea",
    "Lugli, Gabriele A."
)

# %%
author_score(
    "Chen, Yang",
    "Chen, Y."
)

# %%
author_score(
    "Smith, John",
    "Chen, Yang"
)

# %%
df["last_name"] = df["normalized_author"].apply(
    lambda x: split_author(x)[0]
)

# %%
df["normalized_author"].isna().sum()

# %%
(df["normalized_author"] == "").sum()

# %%
df[df["normalized_author"] == ""]

# %%
df = df[df["normalized_author"] != ""].copy()

# %%
df.shape

# %%
df["last_name"] = df["normalized_author"].apply(
    lambda x: split_author(x)[0]
)

# %%
def split_author(author):

    if pd.isna(author):
        return "", ""

    author = str(author).strip()

    if author == "":
        return "", ""

    if "," in author:
        parts = author.split(",", 1)

        last = parts[0].strip()

        first = parts[1].strip() if len(parts) > 1 else ""

        return last, first

    parts = author.split()

    if len(parts) == 0:
        return "", ""

    if len(parts) == 1:
        return parts[0], ""

    return parts[0], " ".join(parts[1:])

# %%
df = df[df["normalized_author"] != ""].copy()

# %%
df.shape

# %%
df["last_name"] = df["normalized_author"].apply(
    lambda x: split_author(x)[0]
)

# %%
last_name_groups = df.groupby("last_name")

# %%
# =====================================================
# AUTHOR NORMALIZATION
# =====================================================

# %% [markdown]
# # Bibliometric Normalization System (BNS)
#
# ## Module 03 - Author Normalization
#
# **Objective**
#
# This notebook identifies and merges author name variants in the Web of Science dataset.
#
# Outputs:
#
# - Merged_Author_Table.xlsx
# - Normalized_WoS_Data.xlsx

# %%
author_groups = {}

for last_name, group in df.groupby("last_name"):
    author_groups[last_name] = (
        group["normalized_author"]
        .dropna()
        .unique()
        .tolist()
    )

# %%
df["last_name"] = df["normalized_author"].apply(
    lambda x: split_author(x)[0]
)

# %%
from rapidfuzz import fuzz

def author_name_similarity(author1, author2):

    author1 = str(author1).strip().lower()
    author2 = str(author2).strip().lower()

    return fuzz.token_sort_ratio(author1, author2)

# %%
author_name_similarity(
    "Lugli, Gabriele Andrea",
    "Lugli, Gabriele A."
)

# %%
def find_candidates(author_list, threshold=90):

    candidates = []

    for i in range(len(author_list)):

        for j in range(i + 1, len(author_list)):

            score = author_name_similarity(
                author_list[i],
                author_list[j]
            )

            if score >= threshold:

                candidates.append({
                    "author_1": author_list[i],
                    "author_2": author_list[j],
                    "score": score
                })

    return candidates

# %%
first_lastname = list(author_groups.keys())[0]

print(first_lastname)

# %%
candidate_pairs = find_candidates(
    author_groups[first_lastname]
)

candidate_pairs

# %%
largest_group = max(
    author_groups.items(),
    key=lambda x: len(x[1])
)

largest_lastname = largest_group[0]

print(largest_lastname)
print(len(largest_group[1]))

# %% [markdown]
# ## 5.1 Affiliation Standardization

# %%
def normalize_affiliation(aff):

    if pd.isna(aff):
        return ""

    aff = str(aff).lower()

    aff = aff.replace("univ.", "university")
    aff = aff.replace("dept.", "department")
    aff = aff.replace("&", "and")

    aff = " ".join(aff.split())

    return aff

# %%
df["normalized_affiliation"] = (
    df["affiliation"]
    .apply(normalize_affiliation)
)

# %%
df[[
    "affiliation",
    "normalized_affiliation"
]].head()

# %% [markdown]
# ## 5.2 Keyword Standardization

# %%
def normalize_keywords(text):

    if pd.isna(text):
        return ""

    text = str(text).lower()

    text = text.replace(";", ",")

    keywords = [
        x.strip()
        for x in text.split(",")
        if x.strip()
    ]

    keywords = sorted(set(keywords))

    return ",".join(keywords)

# %%
df["normalized_keywords"] = (
    df["keywords"]
    .apply(normalize_keywords)
)

# %%
df[[
    "keywords",
    "normalized_keywords"
]].head()

# %% [markdown]
# BÖLÜM 3 — Publication Year

# %%
df["year"] = pd.to_numeric(
    df["year"],
    errors="coerce"
)

# %%
df["year"].describe()

# %% [markdown]
# BÖLÜM 4 — Name Similarity

# %%
from rapidfuzz import fuzz

def name_similarity(a, b):

    return fuzz.token_sort_ratio(
        str(a),
        str(b)
    )

# %% [markdown]
# BÖLÜM 5 — Affiliation Similarity

# %%
def affiliation_similarity(a, b):

    return fuzz.token_sort_ratio(
        str(a),
        str(b)
    )

# %% [markdown]
# BÖLÜM 6 — Keyword Similarity

# %%
def keyword_similarity(a, b):

    return fuzz.token_sort_ratio(
        str(a),
        str(b)
    )

# %% [markdown]
# BÖLÜM 7 — Year Similarity

# %%
def year_similarity(y1, y2):

    if pd.isna(y1) or pd.isna(y2):
        return 50

    diff = abs(y1 - y2)

    if diff == 0:
        return 100

    if diff <= 2:
        return 80

    if diff <= 5:
        return 60

    return 20

# %% [markdown]
# ## 5.3 Author Confidence Score

# %%
def confidence_score(
    author1,
    author2,
    aff1,
    aff2,
    key1,
    key2,
    year1,
    year2
):

    name_score = name_similarity(author1, author2)

    aff_score = affiliation_similarity(aff1, aff2)

    keyword_score = keyword_similarity(key1, key2)

    year_score = year_similarity(year1, year2)

    final_score = (
        name_score * 0.50
        + aff_score * 0.25
        + keyword_score * 0.15
        + year_score * 0.10
    )

    return {
        "name": round(name_score,2),
        "affiliation": round(aff_score,2),
        "keywords": round(keyword_score,2),
        "year": round(year_score,2),
        "confidence": round(final_score,2)
    }

# %%
confidence_score(

    "Lugli, Gabriele Andrea",
    "Lugli, Gabriele A.",

    "University of Parma",
    "Univ. of Parma",

    "microbiome, probiotics",
    "probiotics, microbiome",

    2022,
    2023
)

# %%
df.head(10)

# %%
row1 = df.iloc[0]
row2 = df.iloc[1]

# %%
confidence_score(

    row1["normalized_author"],
    row2["normalized_author"],

    row1["normalized_affiliation"],
    row2["normalized_affiliation"],

    row1["normalized_keywords"],
    row2["normalized_keywords"],

    row1["year"],
    row2["year"]

)

# %%
def evaluate_pair(row1,row2):

    score = confidence_score(

        row1["normalized_author"],
        row2["normalized_author"],

        row1["normalized_affiliation"],
        row2["normalized_affiliation"],

        row1["normalized_keywords"],
        row2["normalized_keywords"],

        row1["year"],
        row2["year"]

    )

    return score

# %%
evaluate_pair(
    df.iloc[0],
    df.iloc[1]
)

# %%
def merge_decision(score):

    if score["confidence"] >= 95:
        return "Automatic Merge"

    elif score["confidence"] >= 85:
        return "Manual Review"

    else:
        return "Different Authors"

# %%
score = evaluate_pair(
    df.iloc[0],
    df.iloc[1]
)

merge_decision(score)

# %% [markdown]
# # 6. Author Merge Engine

# %%
merge_table = []

# %%
for lastname in author_groups:

    print(lastname)

# %%
for lastname in author_groups:

    authors = author_groups[lastname]

    print(lastname, len(authors))

# %%
for lastname in author_groups:

    authors = author_groups[lastname]

    if len(authors) < 2:
        continue

    print(lastname)

# %%
merge_table = []

for lastname in author_groups:

    authors = author_groups[lastname]

    if len(authors) < 2:
        continue

    for i in range(len(authors)):

        for j in range(i+1, len(authors)):

            merge_table.append({

                "lastname": lastname,

                "author1": authors[i],

                "author2": authors[j]

            })

# %%
len(merge_df)

# %%
author_lookup = (
    df
    .drop_duplicates("normalized_author")
    .set_index("normalized_author", drop=False)
)

# %%
author_lookup.head()

# %%
scores = []

for _, row in merge_df.iterrows():

    try:

        a = author_lookup.loc[row["author1"]]
        b = author_lookup.loc[row["author2"]]

        result = confidence_score(

            a["normalized_author"],
            b["normalized_author"],

            a["normalized_affiliation"],
            b["normalized_affiliation"],

            a["normalized_keywords"],
            b["normalized_keywords"],

            a["year"],
            b["year"]

        )

        scores.append(result["confidence"])

    except Exception as e:

        print("HATA:")
        print(row["author1"])
        print(row["author2"])
        print(e)

        break

# %%
drop=False

# %%
scores = []

for _, row in merge_df.iterrows():

    a = author_lookup.loc[row["author1"]]
    b = author_lookup.loc[row["author2"]]

    result = confidence_score(

        a["normalized_author"],
        b["normalized_author"],

        a["normalized_affiliation"],
        b["normalized_affiliation"],

        a["normalized_keywords"],
        b["normalized_keywords"],

        a["year"],
        b["year"]

    )

    scores.append(result["confidence"])

# %% [markdown]
# # 7. Canonical Author Selection

# %%
automatic_merge = merge_df[
    merge_df["decision"] == "Automatic Merge"
].copy()

automatic_merge.head()

# %%
len(automatic_merge)

# %%
def choose_canonical_name(author1, author2):

    # Daha uzun isim tercih edilir
    if len(author1) >= len(author2):
        return author1
    else:
        return author2

# %%
automatic_merge["canonical_author"] = automatic_merge.apply(
    lambda row: choose_canonical_name(
        row["author1"],
        row["author2"]
    ),
    axis=1
)

# %%
automatic_merge[
    ["author1", "author2", "canonical_author", "confidence"]
].head(20)

# %%
merge_df.columns.tolist()

# %%
author_lookup.head()

# %%
author_lookup.columns.tolist()

# %%
row = merge_df.iloc[0]

row

# %%
a = author_lookup.loc[row["author1"]]
b = author_lookup.loc[row["author2"]]

print(a["normalized_author"])
print(b["normalized_author"])

# %%
confidence_score(

    a["normalized_author"],
    b["normalized_author"],

    a["normalized_affiliation"],
    b["normalized_affiliation"],

    a["normalized_keywords"],
    b["normalized_keywords"],

    a["year"],
    b["year"]
)

# %% [markdown]
# # =====================================================
# # Bibliometric Normalization System (BNS)
# # Module 04 - Merge Engine
# # Version : 1.0
# # Author  : <Samet UÇAK>
# # =====================================================

# %% [markdown]
# # Bibliometric Normalization System (BNS)
#
# ## Module 04 — Merge Engine
#
# Bu modül aynı araştırmacıya ait isim varyasyonlarını tespit eder, güven puanını hesaplar ve Canonical Author tablosunu oluşturur.

# %%
print("="*70)
print("BIBLIOMETRIC NORMALIZATION SYSTEM")
print("MODULE 04 - MERGE ENGINE")
print("="*70)

# %%
required_columns = [
    "normalized_author",
    "last_name",
    "normalized_affiliation",
    "normalized_keywords",
    "year"
]

missing = [c for c in required_columns if c not in df.columns]

if missing:
    print("Eksik sütunlar:")
    print(missing)
else:
    print("✓ Tüm gerekli sütunlar mevcut.")

# %%
author_lookup = (
    df
    .drop_duplicates("normalized_author")
    .set_index("normalized_author", drop=False)
)

# %%
print(author_lookup.shape)

# %%
merge_table = []

for lastname, authors in author_groups.items():

    if len(authors) < 2:
        continue

    for i in range(len(authors)):

        for j in range(i+1, len(authors)):

            merge_table.append({

                "lastname": lastname,

                "author1": authors[i],

                "author2": authors[j]

            })

# %%
merge_df = pd.DataFrame(merge_table)

print(merge_df.shape)
merge_df.head()

# %%
merge_df["confidence"] = merge_df.apply(
    calculate_confidence,
    axis=1
)

# %%
calculate_confidence

# %%
def calculate_confidence(row):

    a = author_lookup.loc[row["author1"]]
    b = author_lookup.loc[row["author2"]]

    result = confidence_score(

        a["normalized_author"],
        b["normalized_author"],

        a["normalized_affiliation"],
        b["normalized_affiliation"],

        a["normalized_keywords"],
        b["normalized_keywords"],

        a["year"],
        b["year"]

    )

    return result["confidence"]

# %%
calculate_confidence(merge_df.iloc[0])

# %%
merge_df["confidence"] = merge_df.apply(
    calculate_confidence,
    axis=1
)

# %%
print("confidence_score:", callable(confidence_score))
print("merge_decision:", callable(merge_decision))

# %%
def calculate_confidence(row):

    author1 = row["author1"]
    author2 = row["author2"]

    a = author_lookup.loc[author1]
    b = author_lookup.loc[author2]

    score = confidence_score(

        a["normalized_author"],
        b["normalized_author"],

        a["normalized_affiliation"],
        b["normalized_affiliation"],

        a["normalized_keywords"],
        b["normalized_keywords"],

        a["year"],
        b["year"]

    )

    return score["confidence"]

# %%
test_row = merge_df.iloc[0]

calculate_confidence(test_row)

# %%
merge_df["confidence"] = merge_df.apply(
    calculate_confidence,
    axis=1
)

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
print("✓ similarity.py başarıyla yüklendi.")

# %%
confidence_score(

    "Lugli, Gabriele Andrea",

    "Lugli, Gabriele A.",

    "University of Parma",

    "University of Parma",

    "microbiome, probiotics",

    "probiotics, microbiome",

    2022,

    2023

)

# %%
from src.merge_engine import (
    build_merge_candidates,
    score_merge_candidates
)

# %%
merge_df = build_merge_candidates(author_groups)

merge_df.head()

# %%
merge_df.shape

# %%
merge_df = score_merge_candidates(

    merge_df,

    author_lookup

)

# %%
merge_df.head()

# %%
from src.merge_engine import (
    build_merge_candidates,
    score_merge_candidates
)

# %%
from src.merge_engine import select_canonical_author

# %% [markdown]
# MODÜL 04 – BÖLÜM 2: Canonical Author Mapping

# %%
automatic_merge = merge_df[
    merge_df["decision"] == "Automatic Merge"
].copy()

print(f"Otomatik birleşecek kayıt sayısı: {len(automatic_merge)}")
automatic_merge.head()

# %%
print(df.shape)

# %%
print(author_groups is not None)

# %%
print(author_lookup.shape)

# %%
from src.merge_engine import (
    build_merge_candidates,
    score_merge_candidates
)

merge_df = build_merge_candidates(author_groups)

print(merge_df.shape)
merge_df.head()

# %%
print(df.columns.tolist())

# %%
author_lookup = (
    df
    .sort_values("times_cited", ascending=False)
    .drop_duplicates(subset="normalized_author")
    .set_index("normalized_author")
)

print(author_lookup.shape)
author_lookup.head()

# %%
merge_df = build_merge_candidates(author_groups)

merge_df = score_merge_candidates(
    merge_df,
    author_lookup
)

merge_df.head()

# %%
import src.merge_engine as me

print(me.__file__)

# %%
import src.similarity as sim

print(dir(sim))

# %%
import src.merge_engine as me

print(me.__file__)
print("confidence_score" in dir(me))
print(dir(me))

# %%
import src.merge_engine as me

print(me.confidence_score)

# %%
importlib.reload(sim)
importlib.reload(me)

print("✓ similarity.py yüklendi")
print("✓ merge_engine.py yüklendi")

# %%
import os

print(os.getcwd())

# %%
import pandas as pd
import importlib

import src.similarity as sim
import src.merge_engine as me

print("Modüller başarıyla yüklendi.")

# %%
from pathlib import Path

data_path = Path("../data")

print("Data klasöründeki dosyalar:\n")

for file in data_path.iterdir():
    print(file.name)

# %%
from pathlib import Path

print("Proje klasöründeki dosya ve klasörler:\n")

for item in Path("..").iterdir():
    print(item.name)

# %%
from pathlib import Path

INPUT_DIR = Path("..") / "input"

print("Input klasöründeki dosyalar:\n")

for file in INPUT_DIR.iterdir():
    print(file.name)

# %%
from pathlib import Path

OUTPUT_DIR = PROJECT_ROOT / "output"

df = pd.read_excel(
    OUTPUT_DIR / "Normalized_WoS_Data.xlsx"
)

print(df.shape)
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[222], line 3
#       1 from pathlib import Path
# ----> 3 OUTPUT_DIR = PROJECT_ROOT / "output"
#       5 df = pd.read_excel(
#       6     OUTPUT_DIR / "Normalized_WoS_Data.xlsx"
#       7 )
#       9 print(df.shape)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Author Full Name', 'Title', 'Publication Name / Source', 'Publication Year', 'Times Cited', 'Abstract', 'Author Keywords', 'Author Address / Affiliation', 'Author']

# %%
df.head(5)
# Out:
#   Unnamed: 0            Author Full Name  \
# 0          1     Hertz, Frederik Boetius
# 1          2  Garmendia, Jenny Valentina
# 2          3         Saraf, Viqar Sayeed
# 3          4                 Kim, Juewon
# 4          5                 Yang, Siwen
#
#                                                Title  \
# 0  Vaginal microbiome following orally administer...
# 1  Microbiota and Recurrent Pregnancy Loss (RPL);...
# 2          Vaginal microbiome: normalcy vs dysbiosis
# 3  Systems-level restoration of vaginal and gut m...
# 4  Effect of Oral Probiotic Lactobacillus rhamnos...
#
#   Publication Name / Source Publication Year Times Cited  \
# 0                     APMIS             2022          10
# 1            MICROORGANISMS             2024          25
# 2  ARCHIVES OF MICROBIOLOGY             2021         145
# 3              ISME JOURNAL             2026           0
# 4                 NUTRIENTS             2020          75
#
#                                             Abstract  \
# 0  Here, we present a longitudinal shotgun sequen...
# 1  Recurrent Pregnancy Loss (RPL) affects 1-2% of...
# 2  It has been long understood that the vaginal m...
# 3  Bacterial vaginosis (BV), often driven by Gard...
# 4  Spontaneous preterm birth is associated with v...
#
#                                      Author Keywords  \
# 0  Vaginal microbiome; healthy microbiome; women;...
# 1  recurrent pregnancy loss (RPL); recurrent impl...
# 2  Vaginal microbiome; Vaginal dysbiosis; Bacteri...
# 3  vaginal dysbiosis; gut-vagina axis; Lactobacil...
# 4  probiotics; pregnancy; bacterial vaginosis; mi...
#
#                         Author Address / Affiliation  \
# 0  [Hertz, Frederik Boetius; Bjornsdottir, Maria ...
# 1  [Garmendia, Jenny Valentina; De Sanctis, Claud...
# 2  [Saraf, Viqar Sayeed; Sheikh, Sohail Aslam; Ah...
# 3  [Kim, Juewon; Kim, Woo-il] Konkuk Univ, Coll M...
# 4  [Yang, Siwen; Challis, John R. G.; Bocking, Al...
#
#                        Author
# 0     Hertz, Frederik Boetius
# 1  Garmendia, Jenny Valentina
# 2         Saraf, Viqar Sayeed
# 3                 Kim, Juewon
# 4                 Yang, Siwen

# %%
from pathlib import Path

OUTPUT_DIR = Path("..") / "output"

print("Output klasörü:\n")

for file in OUTPUT_DIR.iterdir():
    print(file.name)

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

INPUT_DIR = PROJECT_ROOT / "output"
OUTPUT_DIR = PROJECT_ROOT / "output"

print("Project Root :", PROJECT_ROOT)
print("Input :", INPUT_DIR)
print("Output:", OUTPUT_DIR)

# %%
import pandas as pd
import importlib

import src.merge_engine as me

importlib.reload(me)

print("Merge Engine yüklendi.")

# %%
df = pd.read_excel(
    INPUT_DIR / "Normalized_WoS_Data.xlsx"
)

print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[226], line 2
#       1 df = pd.read_excel(
# ----> 2     INPUT_DIR / "Normalized_WoS_Data.xlsx"
#       3 )
#       5 print(df.shape)
#       6 df.head()
#
# NameError: name 'INPUT_DIR' is not defined

# %%
import importlib
import src.merge_engine as me

importlib.reload(me)

print("merge_engine.py yeniden yüklendi.")

# %%
author_lookup = me.build_author_lookup(df)

print(author_lookup.shape)

# %%
print(df["times_cited"].dtype)

print(df["times_cited"].head(20))

# %%
import importlib
import src.merge_engine as me

importlib.reload(me)

print("merge_engine yeniden yüklendi.")

# %%
author_lookup = me.build_author_lookup(df)

print(author_lookup.shape)

# %%
author_groups = me.build_author_groups(df)

print(f"Soyadı grubu sayısı: {len(author_groups)}")

# %%
merge_df = me.build_merge_candidates(author_groups)

print(merge_df.shape)

merge_df.head()

# %%
merge_df = me.score_merge_candidates(
    merge_df,
    author_lookup
)

print(merge_df.shape)

merge_df.head()

# %%
print(author_lookup.columns.tolist())

# %%
print(author_lookup.index.name)

# %%
import importlib
import src.merge_engine as me

importlib.reload(me)

# %%
import src.merge_engine as me

print(me.__file__)

# %%
import inspect

print(inspect.getsource(me.calculate_confidence))

# %%
import importlib
import src.merge_engine as me

me = importlib.reload(me)

print("Reload başarılı")

# %%
print(me.calculate_confidence)
print(me.score_merge_candidates)

# %%
import inspect

print(inspect.getsource(me.score_merge_candidates))

# %%
row = merge_df.iloc[0]

print(row)

# %%
a = author_lookup.loc[row["author1"]]
b = author_lookup.loc[row["author2"]]

print(a)
print()
print(b)

# %%
print(type(a))
print(type(b))

# %%
import src.similarity as sim

score = sim.confidence_score(
    row["author1"],
    row["author2"],
    a["normalized_affiliation"],
    b["normalized_affiliation"],
    a["normalized_keywords"],
    b["normalized_keywords"],
    a["year"],
    b["year"]
)

print(score)

# %%
print(me.calculate_confidence(
    merge_df.iloc[0],
    author_lookup
))

# %%
merge_df.iloc[:5].apply(
    lambda r: me.calculate_confidence(r, author_lookup),
    axis=1
)

# %%
import importlib
import src.merge_engine as me

me = importlib.reload(me)

# %%
merge_df = me.score_merge_candidates(
    merge_df,
    author_lookup
)

# %%
print(merge_df.head())

# %%
merge_df["decision"].value_counts()

# %%
automatic_merge = merge_df[
    merge_df["decision"] == "Automatic Merge"
].copy()

print(automatic_merge.shape)

automatic_merge.head()

# %%
automatic_merge["canonical_author"] = automatic_merge.apply(

    lambda row: me.select_canonical_author(
        row["author1"],
        row["author2"]
    ),

    axis=1

)

automatic_merge.head()

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)

print("indicator.py yüklendi.")

# %%
import os
from pathlib import Path

print("Mevcut dizin:", Path.cwd())

# %%
import os
from pathlib import Path

os.chdir("..")

PROJECT_ROOT = Path.cwd()

print("Proje dizini:", PROJECT_ROOT)
print("src var mı?", (PROJECT_ROOT / "src").exists())
print("__init__.py var mı?", (PROJECT_ROOT / "src" / "__init__.py").exists())

# %%
import sys

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import importlib
import src.indicator as ind

importlib.reload(ind)

print("indicator.py başarıyla yüklendi.")

# %%
from pathlib import Path

src_path = PROJECT_ROOT / "src"

print("src içeriği:\n")

for file in src_path.iterdir():
    print(file.name)

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)

print("indicator.py başarıyla yüklendi.")

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)

print("indicator.py yüklendi.")

# %%
df["times_cited"] = (
    pd.to_numeric(
        df["times_cited"],
        errors="coerce"
    )
    .fillna(0)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'times_cited'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[208], line 3
#       1 df["times_cited"] = (
#       2     pd.to_numeric(
# ----> 3         df["times_cited"],
#       4         errors="coerce"
#       5     )
#       6     .fillna(0)
#       7 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'times_cited'

# %%
import pandas as pd
import numpy as np
import importlib

# %%
df["times_cited"] = (
    pd.to_numeric(
        df["times_cited"],
        errors="coerce"
    )
    .fillna(0)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'times_cited'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[210], line 3
#       1 df["times_cited"] = (
#       2     pd.to_numeric(
# ----> 3         df["times_cited"],
#       4         errors="coerce"
#       5     )
#       6     .fillna(0)
#       7 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'times_cited'

# %%
print(df.columns.tolist())
print(df.shape)
# Out:
# ['Unnamed: 0', 'Author Full Name', 'Title', 'Publication Name / Source', 'Publication Year', 'Times Cited', 'Abstract', 'Author Keywords', 'Author Address / Affiliation', 'Author']
# (12198, 10)

# %%
print(PROJECT_ROOT)
print(type(PROJECT_ROOT))
# Out:
# C:\Users\sametucak
# <class 'str'>

# %%
from pathlib import Path

PROJECT_ROOT = Path(PROJECT_ROOT)

OUTPUT_DIR = PROJECT_ROOT / "output"

df = pd.read_excel(
    OUTPUT_DIR / "Normalized_WoS_Data.xlsx"
)

print(df.shape)
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[230], line 7
#       3 PROJECT_ROOT = Path(PROJECT_ROOT)
#       5 OUTPUT_DIR = PROJECT_ROOT / "output"
# ----> 7 df = pd.read_excel(
#       8     OUTPUT_DIR / "Normalized_WoS_Data.xlsx"
#       9 )
#      11 print(df.shape)
#      12 print(df.columns.tolist())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sametucak\\output\\Normalized_WoS_Data.xlsx'

# %%
from pathlib import Path
import os
import sys

# Proje klasörüne git
os.chdir(r"C:\Users\sametucak\Bibliometric-Normalization-System (BNS)")

PROJECT_ROOT = Path.cwd()
INPUT_DIR = PROJECT_ROOT / "input"
OUTPUT_DIR = PROJECT_ROOT / "output"

# src klasörünü Python'a tanıt
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
print("INPUT_DIR var mı?:", INPUT_DIR.exists())
print("OUTPUT_DIR var mı?:", OUTPUT_DIR.exists())
print("src var mı?:", (PROJECT_ROOT / "src").exists())
# Out:
# PROJECT_ROOT: C:\Users\sametucak\Bibliometric-Normalization-System (BNS)
# INPUT_DIR var mı?: True
# OUTPUT_DIR var mı?: True
# src var mı?: True

# %%
import pandas as pd

df = pd.read_excel(OUTPUT_DIR / "Normalized_WoS_Data.xlsx")

print(df.shape)
print(df.columns.tolist())
# Out:
# (12197, 13)
# ['author_full_name', 'title', 'journal', 'year', 'times_cited', 'abstract', 'keywords', 'affiliation', 'author', 'normalized_author', 'last_name', 'normalized_affiliation', 'normalized_keywords']

# %%
df["times_cited"] = (
    pd.to_numeric(df["times_cited"], errors="coerce")
    .fillna(0)
    .astype(int)
)

# %%
print(df["times_cited"].dtype)
# Out:
# int32

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)

pub = ind.publication_count(df)

print(pub.shape)
pub.head()
# Out:
# (10381, 2)
#          normalized_author  publication_count
# 0  AL-Ishaq, Raghad Khalid                  1
# 1      AL-Smadi, Khadeejeh                  1
# 2         Aagaard, Kjersti                  1
# 3            Aakko, Juhani                  1
# 4       Aardema, Niklas D.                  1

# %%
cit = ind.citation_count(df)

print(cit.shape)
cit.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[242], line 1
# ----> 1 cit = ind.citation_count(df)
#       3 print(cit.shape)
#       4 cit.head()
#
# AttributeError: module 'src.indicator' has no attribute 'citation_count'

# %%
import src.indicator as ind

print(dir(ind))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'np', 'pd', 'publication_count']

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)

print(dir(ind))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'citation_count', 'np', 'pd', 'publication_count']

# %%
cit = ind.citation_count(df)

print(cit.shape)

cit.head()
# Out:
# (10381, 2)
#          normalized_author  citation_count
# 0  AL-Ishaq, Raghad Khalid              17
# 1      AL-Smadi, Khadeejeh              36
# 2         Aagaard, Kjersti             537
# 3            Aakko, Juhani              12
# 4       Aardema, Niklas D.              13

# %%
author_metrics = pub.merge(
    cit,
    on="normalized_author",
    how="left"
)

print(author_metrics.shape)

author_metrics.head()
# Out:
# (10381, 3)
#          normalized_author  publication_count  citation_count
# 0  AL-Ishaq, Raghad Khalid                  1              17
# 1      AL-Smadi, Khadeejeh                  1              36
# 2         Aagaard, Kjersti                  1             537
# 3            Aakko, Juhani                  1              12
# 4       Aardema, Niklas D.                  1              13

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)
# Out:
# <module 'src.indicator' from 'C:\\Users\\sametucak\\Bibliometric-Normalization-System (BNS)\\src\\indicator.py'>

# %%
avg = ind.average_citations(df)

print(avg.shape)

avg.head()
# Out:
# (10381, 2)
#          normalized_author  average_citations
# 0  AL-Ishaq, Raghad Khalid               17.0
# 1      AL-Smadi, Khadeejeh               36.0
# 2         Aagaard, Kjersti              537.0
# 3            Aakko, Juhani               12.0
# 4       Aardema, Niklas D.               13.0

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)
# Out:
# <module 'src.indicator' from 'C:\\Users\\sametucak\\Bibliometric-Normalization-System (BNS)\\src\\indicator.py'>

# %%
h = ind.h_index(df)

print(h.shape)

h.head()
# Out:
# (10381, 2)
#          normalized_author  h_index
# 0  AL-Ishaq, Raghad Khalid        1
# 1      AL-Smadi, Khadeejeh        1
# 2         Aagaard, Kjersti        1
# 3            Aakko, Juhani        1
# 4       Aardema, Niklas D.        1

# %%
author_metrics = (
    pub
    .merge(cit, on="normalized_author")
    .merge(avg, on="normalized_author")
    .merge(h, on="normalized_author")
)

print(author_metrics.shape)

author_metrics.head()
# Out:
# (10381, 5)
#          normalized_author  publication_count  citation_count  \
# 0  AL-Ishaq, Raghad Khalid                  1              17
# 1      AL-Smadi, Khadeejeh                  1              36
# 2         Aagaard, Kjersti                  1             537
# 3            Aakko, Juhani                  1              12
# 4       Aardema, Niklas D.                  1              13
#
#    average_citations  h_index
# 0               17.0        1
# 1               36.0        1
# 2              537.0        1
# 3               12.0        1
# 4               13.0        1

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)
# Out:
# <module 'src.indicator' from 'C:\\Users\\sametucak\\Bibliometric-Normalization-System (BNS)\\src\\indicator.py'>

# %%
i10 = ind.i10_index(df)

print(i10.shape)

i10.head()
# Out:
# (10381, 2)
#          normalized_author  i10_index
# 0  AL-Ishaq, Raghad Khalid          1
# 1      AL-Smadi, Khadeejeh          1
# 2         Aagaard, Kjersti          1
# 3            Aakko, Juhani          1
# 4       Aardema, Niklas D.          1

# %%
author_metrics = (
    pub
    .merge(cit, on="normalized_author")
    .merge(avg, on="normalized_author")
    .merge(h, on="normalized_author")
    .merge(i10, on="normalized_author")
)

print(author_metrics.shape)

author_metrics.head()
# Out:
# (10381, 6)
#          normalized_author  publication_count  citation_count  \
# 0  AL-Ishaq, Raghad Khalid                  1              17
# 1      AL-Smadi, Khadeejeh                  1              36
# 2         Aagaard, Kjersti                  1             537
# 3            Aakko, Juhani                  1              12
# 4       Aardema, Niklas D.                  1              13
#
#    average_citations  h_index  i10_index
# 0               17.0        1          1
# 1               36.0        1          1
# 2              537.0        1          1
# 3               12.0        1          1
# 4               13.0        1          1

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)
# Out:
# <module 'src.indicator' from 'C:\\Users\\sametucak\\Bibliometric-Normalization-System (BNS)\\src\\indicator.py'>

# %%
first = ind.first_publication_year(df)

last = ind.last_publication_year(df)

age = ind.academic_age(df)

print(first.head())

print(last.head())

print(age.head())
# Out:
#          normalized_author first_publication_year
# 0  AL-Ishaq, Raghad Khalid                   2023
# 1      AL-Smadi, Khadeejeh                   2023
# 2         Aagaard, Kjersti                   2012
# 3            Aakko, Juhani                   2015
# 4       Aardema, Niklas D.                   2021
#          normalized_author last_publication_year
# 0  AL-Ishaq, Raghad Khalid                  2023
# 1      AL-Smadi, Khadeejeh                  2023
# 2         Aagaard, Kjersti                  2012
# 3            Aakko, Juhani                  2015
# 4       Aardema, Niklas D.                  2021
#          normalized_author academic_age
# 0  AL-Ishaq, Raghad Khalid            1
# 1      AL-Smadi, Khadeejeh            1
# 2         Aagaard, Kjersti            1
# 3            Aakko, Juhani            1
# 4       Aardema, Niklas D.            1

# %%
import importlib
import src.indicator as ind

importlib.reload(ind)
# Out:
# <module 'src.indicator' from 'C:\\Users\\sametucak\\Bibliometric-Normalization-System (BNS)\\src\\indicator.py'>

# %%
metrics = ind.build_author_metrics(df)

print(metrics.shape)

metrics.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[280], line 1
# ----> 1 metrics = ind.build_author_metrics(df)
#       3 print(metrics.shape)
#       5 metrics.head()
#
# AttributeError: module 'src.indicator' has no attribute 'build_author_metrics'

# %%
print(dir(ind))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'academic_age', 'average_citations', 'citation_count', 'first_publication_year', 'h_index', 'i10_index', 'last_publication_year', 'np', 'pd', 'publication_count']

# %%
import src.indicator as ind

print(ind.__file__)
# Out:
# C:\Users\sametucak\Bibliometric-Normalization-System (BNS)\src\indicator.py

# %%
import importlib
import src.indicator as ind

ind = importlib.reload(ind)

print(dir(ind))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'academic_age', 'average_citations', 'build_author_metrics', 'citation_count', 'first_publication_year', 'h_index', 'i10_index', 'last_publication_year', 'np', 'pd', 'publication_count']

# %%
metrics = ind.build_author_metrics(df)

print(metrics.shape)

metrics.head()
# Out:
# (10381, 9)
#          normalized_author  publication_count  citation_count  \
# 0  AL-Ishaq, Raghad Khalid                  1              17
# 1      AL-Smadi, Khadeejeh                  1              36
# 2         Aagaard, Kjersti                  1             537
# 3            Aakko, Juhani                  1              12
# 4       Aardema, Niklas D.                  1              13
#
#    average_citations  h_index  i10_index first_publication_year  \
# 0               17.0        1          1                   2023
# 1               36.0        1          1                   2023
# 2              537.0        1          1                   2012
# 3               12.0        1          1                   2015
# 4               13.0        1          1                   2021
#
#   last_publication_year academic_age
# 0                  2023            1
# 1                  2023            1
# 2                  2012            1
# 3                  2015            1
# 4                  2021            1
